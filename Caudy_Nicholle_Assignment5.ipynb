# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.9801495006250001, score: 14
# Scores: (min: 10, avg: 12, max: 14)
#
# Run: 3, exploration: 0.9000874278732445, score: 18
# Scores: (min: 10, avg: 14, max: 18)
#
# Run: 4, exploration: 0.8142285204175609, score: 21
# Scores: (min: 10, avg: 15.75, max: 21)
#
# Run: 5, exploration: 0.7328768546436799, score: 22
# Scores: (min: 10, avg: 17, max: 22)
#
# Run: 6, exploration: 0.6242658676435396, score: 33
# Scores: (min: 10, avg: 19.666666666666668, max: 33)
#
# Run: 7, exploration: 0.5590843898207511, score: 23
# Scores: (min: 10, avg: 20.142857142857142, max: 33)
#
# Run: 8, exploration: 0.4484282034609769, score: 45
# Scores: (min: 10, avg: 23.25, max: 45)
#
# Run: 9, exploration: 0.43080185560799106, score: 9
# Scores: (min: 9, avg: 21.666666666666668, max: 45)
#
# Run: 10, exploration: 0.40769130904675194, score: 12
# Scores: (min: 9, avg: 20.7, max: 45)
#
# Run: 11, exploration: 0.3858205374665315, score: 12
# Scores: (min: 9, avg: 19.90909090909091, max: 45)
#
# Run: 12, exploration: 0.3455358541129786, score: 23
# Scores: (min: 9, avg: 20.166666666666668, max: 45)
#
# Run: 13, exploration: 0.30945741577570285, score: 23
# Scores: (min: 9, avg: 20.384615384615383, max: 45)
#
# Run: 14, exploration: 0.29729358661854943, score: 9
# Scores: (min: 9, avg: 19.571428571428573, max: 45)
#
# Run: 15, exploration: 0.28134514724562876, score: 12
# Scores: (min: 9, avg: 19.066666666666666, max: 45)
#
# Run: 16, exploration: 0.2702863258025825, score: 9
# Scores: (min: 9, avg: 18.4375, max: 45)
#
# Run: 17, exploration: 0.20931540516921554, score: 52
# Scores: (min: 9, avg: 20.41176470588235, max: 52)
#
# Run: 18, exploration: 0.19318370215794672, score: 17
# Scores: (min: 9, avg: 20.22222222222222, max: 52)
#
# Run: 19, exploration: 0.16538114245489302, score: 32
# Scores: (min: 9, avg: 20.842105263157894, max: 52)
#
# Run: 20, exploration: 0.12365869841532712, score: 59
# Scores: (min: 9, avg: 22.75, max: 59)
#
# Run: 21, exploration: 0.089273984641318, score: 66
# Scores: (min: 9, avg: 24.80952380952381, max: 66)
#
# Run: 22, exploration: 0.0677632708131484, score: 56
# Scores: (min: 9, avg: 26.227272727272727, max: 66)
#
# Run: 23, exploration: 0.04583472801998072, score: 79
# Scores: (min: 9, avg: 28.52173913043478, max: 79)
#
# Run: 24, exploration: 0.03904210656169572, score: 33
# Scores: (min: 9, avg: 28.708333333333332, max: 79)
#
# Run: 25, exploration: 0.02904658009432929, score: 60
# Scores: (min: 9, avg: 29.96, max: 79)
#
# Run: 26, exploration: 0.013832827362230486, score: 149
# Scores: (min: 9, avg: 34.53846153846154, max: 149)
#
# Run: 27, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 36.148148148148145, max: 149)
#
# Run: 28, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 37.42857142857143, max: 149)
#
# Run: 29, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 43.48275862068966, max: 213)
#
# Run: 30, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 49.3, max: 218)
#
# Run: 31, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 53.54838709677419, max: 218)
#
# Run: 32, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 57.40625, max: 218)
#
# Run: 33, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 59.75757575757576, max: 218)
#
# Run: 34, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 64.41176470588235, max: 218)
#
# Run: 35, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 67.6, max: 218)
#
# Run: 36, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 70.22222222222223, max: 218)
#
# Run: 37, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 72.1891891891892, max: 218)
#
# Run: 38, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 76.73684210526316, max: 245)
#
# Run: 39, exploration: 0.01, score: 318
# Scores: (min: 9, avg: 82.92307692307692, max: 318)
#
# Run: 40, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 84.75, max: 318)
#
# Run: 41, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 88.1219512195122, max: 318)
#
# Run: 42, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 91.69047619047619, max: 318)
#
# Run: 43, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 94.20930232558139, max: 318)
#
# Run: 44, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 95.56818181818181, max: 318)
#
# Run: 45, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 97.33333333333333, max: 318)
#
# Run: 46, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 98.82608695652173, max: 318)
#
# Run: 47, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 100.51063829787235, max: 318)
#
# Run: 48, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 101.75, max: 318)
#
# Run: 49, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 103.40816326530613, max: 318)
#
# Run: 50, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 106, max: 318)
#
# Run: 51, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 107.50980392156863, max: 318)
#
# Run: 52, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 108.38461538461539, max: 318)
#
# Run: 53, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 110.01886792452831, max: 318)
#
# Run: 54, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 110.72222222222223, max: 318)
#
# Run: 55, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 111.63636363636364, max: 318)
#
# Run: 56, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 112.875, max: 318)
#
# Run: 57, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 113.75438596491227, max: 318)
#
# Run: 58, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 115.01724137931035, max: 318)
#
# Run: 59, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 115.89830508474576, max: 318)
#
# Run: 60, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 116.7, max: 318)
#
# Run: 61, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 117.22950819672131, max: 318)
#
# Run: 62, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 117.79032258064517, max: 318)
#
# Run: 63, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 117.92063492063492, max: 318)
#
# Run: 64, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 118.421875, max: 318)
#
# Run: 65, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 119, max: 318)
#
# Run: 66, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 119.68181818181819, max: 318)
#
# Run: 67, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 120.74626865671642, max: 318)
#
# Run: 68, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 121.63235294117646, max: 318)
#
# Run: 69, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 123.02898550724638, max: 318)
#
# Run: 70, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 123.17142857142858, max: 318)
#
# Run: 71, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 123.50704225352112, max: 318)
#
# Run: 72, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 123.80555555555556, max: 318)
#
# Run: 73, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 123.06849315068493, max: 318)
#
# Run: 74, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 121.54054054054055, max: 318)
#
# Run: 75, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 120.06666666666666, max: 318)
#
# Run: 76, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 120.8157894736842, max: 318)
#
# Run: 77, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 121.85714285714286, max: 318)
#
# Run: 78, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 122.03846153846153, max: 318)
#
# Run: 79, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 123.12658227848101, max: 318)
#
# Run: 80, exploration: 0.01, score: 471
# Scores: (min: 9, avg: 127.475, max: 471)
#
# Run: 81, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 128.1851851851852, max: 471)
#
# Run: 82, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 128.5487804878049, max: 471)
#
# Run: 83, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 128.9277108433735, max: 471)
#
# Run: 84, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 129.26190476190476, max: 471)
#
# Run: 85, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 129.56470588235294, max: 471)
#
# Run: 86, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 130.15116279069767, max: 471)
#
# Run: 87, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 130.6206896551724, max: 471)
#
# Run: 88, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 129.9090909090909, max: 471)
#
# Run: 89, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 130.3370786516854, max: 471)
#
# Run: 90, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 131.66666666666666, max: 471)
# Run: 91, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 132.01098901098902, max: 471)
#
# Run: 92, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 132.5108695652174, max: 471)
#
# Run: 93, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 132.50537634408602, max: 471)
#
# Run: 94, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 131.59574468085106, max: 471)
#
# Run: 95, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 132.17894736842106, max: 471)
#
# Run: 96, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 132.28125, max: 471)
#
# Run: 97, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 132.55670103092783, max: 471)
#
# Run: 98, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 134.03061224489795, max: 471)
#
# Run: 99, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 134.44444444444446, max: 471)
#
# Run: 100, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 134.66, max: 471)
#
# Run: 101, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 136.29, max: 471)
#
# Run: 102, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 137.6, max: 471)
#
# Run: 103, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 139.16, max: 471)
#
# Run: 104, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 140.43, max: 471)
#
# Run: 105, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 141.83, max: 471)
#
# Run: 106, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 143.15, max: 471)
#
# Run: 107, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 144.83, max: 471)
#
# Run: 108, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 145.68, max: 471)
#
# Run: 109, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 147.22, max: 471)
#
# Run: 110, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 148.8, max: 471)
#
# Run: 111, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 150.46, max: 471)
#
# Run: 112, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 151.78, max: 471)
#
# Run: 113, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 153.27, max: 471)
#
# Run: 114, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 154.97, max: 471)
#
# Run: 115, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 156.54, max: 471)
#
# Run: 116, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 158.26, max: 471)
#
# Run: 117, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 159.9, max: 471)
#
# Run: 118, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 161.33, max: 471)
#
# Run: 119, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 162.6, max: 471)
#
# Run: 120, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 163.8, max: 471)
#
# Run: 121, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 165.04, max: 471)
#
# Run: 122, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 166.35, max: 471)
#
# Run: 123, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 167.04, max: 471)
#
# Run: 124, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 168.45, max: 471)
#
# Run: 125, exploration: 0.01, score: 323
# Scores: (min: 10, avg: 171.08, max: 471)
#
# Run: 126, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 170.29, max: 471)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 169.61, max: 471)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 168.99, max: 471)
#
# Run: 129, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 166.97, max: 471)
#
# Run: 130, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 166.91, max: 471)
#
# Run: 131, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 167.56, max: 471)
#
# Run: 132, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 167.63, max: 471)
#
# Run: 133, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 168.13, max: 471)
#
# Run: 134, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 168.09, max: 471)
#
# Run: 135, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 167.73, max: 471)
#
# Run: 136, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 167.5, max: 471)
#
# Run: 137, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 168.24, max: 471)
#
# Run: 138, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 167.52, max: 471)
#
# Run: 139, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 165.93, max: 471)
#
# Run: 140, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 166.35, max: 471)
#
# Run: 141, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 165.8, max: 471)
#
# Run: 142, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 165.09, max: 471)
#
# Run: 143, exploration: 0.01, score: 327
# Scores: (min: 10, avg: 166.36, max: 471)
#
# Run: 144, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 166.8, max: 471)
#
# Run: 145, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 166.68, max: 471)
#
# Run: 146, exploration: 0.01, score: 228
# Scores: (min: 10, avg: 167.3, max: 471)
#
# Run: 147, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 167.71, max: 471)
#
# Run: 148, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 167.62, max: 471)
#
# Run: 149, exploration: 0.01, score: 325
# Scores: (min: 10, avg: 169.04, max: 471)
#
# Run: 150, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 168.16, max: 471)
#
# Run: 151, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 167.73, max: 471)
#
# Run: 152, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 167.64, max: 471)
#
# Run: 153, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 167.1, max: 471)
#
# Run: 154, exploration: 0.01, score: 391
# Scores: (min: 10, avg: 169.53, max: 471)
#
# Run: 155, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 169.69, max: 471)
#
# Run: 156, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 169.55, max: 471)
#
# Run: 157, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 169.24, max: 471)
#
# Run: 158, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 168.85, max: 471)
#
# Run: 159, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 168.98, max: 471)
#
# Run: 160, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 169.07, max: 471)
#
# Run: 161, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 169.42, max: 471)
#
# Run: 162, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 168.16, max: 471)
#
# Run: 163, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 167, max: 471)
#
# Run: 164, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 165.62, max: 471)
#
# Run: 165, exploration: 0.01, score: 268
# Scores: (min: 10, avg: 166.74, max: 471)
#
# Run: 166, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 166.6, max: 471)
#
# Run: 167, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 164.85, max: 471)
#
# Run: 168, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 164.53, max: 471)
#
# Run: 169, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 163.78, max: 471)
#
# Run: 170, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 163.83, max: 471)
#
# Run: 171, exploration: 0.01, score: 478
# Scores: (min: 10, avg: 167.14, max: 478)
#
# Run: 172, exploration: 0.01, score: 289
# Scores: (min: 10, avg: 168.58, max: 478)
#
# Run: 173, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 169.55, max: 478)
#
# Run: 174, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 171.39, max: 478)
#
# Run: 175, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 173.25, max: 478)
#
# Run: 176, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 173.22, max: 478)
#
# Run: 177, exploration: 0.01, score: 361
# Scores: (min: 10, avg: 174.82, max: 478)
#
# Run: 178, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 175.71, max: 478)
#
# Run: 179, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 175.29, max: 478)
#
# Run: 180, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 172.39, max: 478)
#
# Run: 181, exploration: 0.01, score: 251
# Scores: (min: 10, avg: 173.05, max: 478)
#
# Run: 182, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 173.61, max: 478)
#
# Run: 183, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 173.38, max: 478)
#
# Run: 184, exploration: 0.01, score: 356
# Scores: (min: 10, avg: 175.37, max: 478)
#
# Run: 185, exploration: 0.01, score: 200
# Scores: (min: 10, avg: 175.82, max: 478)
#
# Run: 186, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 175.78, max: 478)
#
# Run: 187, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 176.5, max: 478)
#
# Run: 188, exploration: 0.01, score: 268
# Scores: (min: 10, avg: 178.5, max: 478)
#
# Run: 189, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 178.64, max: 478)
#
# Run: 190, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 178.04, max: 478)
# Run: 191, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 178.07, max: 478)
#
# Run: 192, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 178.36, max: 478)
#
# Run: 193, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 178.97, max: 478)
#
# Run: 194, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 180.21, max: 478)
#
# Run: 195, exploration: 0.01, score: 279
# Scores: (min: 10, avg: 181.13, max: 478)
#
# Run: 196, exploration: 0.01, score: 346
# Scores: (min: 10, avg: 183.17, max: 478)
#
# Run: 197, exploration: 0.01, score: 301
# Scores: (min: 10, avg: 184.59, max: 478)
#
# Run: 198, exploration: 0.01, score: 321
# Scores: (min: 10, avg: 185.03, max: 478)
#
# Run: 199, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 185.3, max: 478)
#
# Run: 200, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 185.19, max: 478)
#
# Run: 201, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 185.07, max: 478)
#
# Run: 202, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 185.18, max: 478)
#
# Run: 203, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 185.37, max: 478)
#
# Run: 204, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 185.88, max: 478)
#
# Run: 205, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 186.4, max: 478)
#
# Run: 206, exploration: 0.01, score: 269
# Scores: (min: 10, avg: 187.44, max: 478)
#
# Run: 207, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 187.32, max: 478)
#
# Run: 208, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 187.35, max: 478)
#
# Run: 209, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 187.39, max: 478)
#
# Run: 210, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 187.39, max: 478)
#
# Run: 211, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 187.77, max: 478)
#
# Run: 212, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 188.21, max: 478)
#
# Run: 213, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 187.84, max: 478)
#
# Run: 214, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 187.85, max: 478)
#
# Run: 215, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 187.46, max: 478)
#
# Run: 216, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 187.09, max: 478)
#
# Run: 217, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 187.39, max: 478)
#
# Run: 218, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 187.23, max: 478)
#
# Run: 219, exploration: 0.01, score: 257
# Scores: (min: 10, avg: 188.21, max: 478)
#
# Run: 220, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 188.22, max: 478)
#
# Run: 221, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 188.23, max: 478)
#
# Run: 222, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 187.95, max: 478)
#
# Run: 223, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 188.25, max: 478)
#
# Run: 224, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 188.86, max: 478)
#
# Run: 225, exploration: 0.01, score: 228
# Scores: (min: 10, avg: 187.91, max: 478)
#
# Run: 226, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 189.77, max: 478)
#
# Run: 227, exploration: 0.01, score: 328
# Scores: (min: 10, avg: 192.95, max: 478)
#
# Run: 228, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 194.86, max: 478)
#
# Run: 229, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 196.56, max: 478)
#
# Solved in 129 runs, 229 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
#learning rate increased to 0.005
#increased GAMMA to 0.99, increase Exploration_MIN to 0.05, decrease Exploration_DECAY to 0.95
  
GAMMA = 0.99  
LEARNING_RATE = 0.005  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.05  
EXPLORATION_DECAY = 0.95  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8061065909263957, score: 63
# Scores: (min: 63, avg: 63, max: 63)
#
# Run: 2, exploration: 0.7147372386831305, score: 25
# Scores: (min: 25, avg: 44, max: 63)
#
# Run: 3, exploration: 0.653073201944699, score: 19
# Scores: (min: 19, avg: 35.666666666666664, max: 63)
#
# Run: 4, exploration: 0.5997278763867329, score: 18
# Scores: (min: 18, avg: 31.25, max: 63)
#
# Run: 5, exploration: 0.5562889678716474, score: 16
# Scores: (min: 16, avg: 28.2, max: 63)
#
# Run: 6, exploration: 0.531750826943791, score: 10
# Scores: (min: 10, avg: 25.166666666666668, max: 63)
#
# Run: 7, exploration: 0.40974000909221303, score: 53
# Scores: (min: 10, avg: 29.142857142857142, max: 63)
#
# Run: 8, exploration: 0.3897078735047413, score: 11
# Scores: (min: 10, avg: 26.875, max: 63)
#
# Run: 9, exploration: 0.36880183088056995, score: 12
# Scores: (min: 10, avg: 25.22222222222222, max: 63)
#
# Run: 10, exploration: 0.3438081748424137, score: 15
# Scores: (min: 10, avg: 24.2, max: 63)
#
# Run: 11, exploration: 0.3141460853680822, score: 19
# Scores: (min: 10, avg: 23.727272727272727, max: 63)
#
# Run: 12, exploration: 0.2743815040481898, score: 28
# Scores: (min: 10, avg: 24.083333333333332, max: 63)
#
# Run: 13, exploration: 0.23725980767521673, score: 30
# Scores: (min: 10, avg: 24.53846153846154, max: 63)
#
# Run: 14, exploration: 0.21248679717794605, score: 23
# Scores: (min: 10, avg: 24.428571428571427, max: 63)
#
# Run: 15, exploration: 0.19318370215794672, score: 20
# Scores: (min: 10, avg: 24.133333333333333, max: 63)
#
# Run: 16, exploration: 0.17919120740315364, score: 16
# Scores: (min: 10, avg: 23.625, max: 63)
#
# Run: 17, exploration: 0.16957841978827493, score: 12
# Scores: (min: 10, avg: 22.941176470588236, max: 63)
#
# Run: 18, exploration: 0.1518722266715875, score: 23
# Scores: (min: 10, avg: 22.944444444444443, max: 63)
#
# Run: 19, exploration: 0.1451730787173275, score: 10
# Scores: (min: 10, avg: 22.263157894736842, max: 63)
#
# Run: 20, exploration: 0.13398475271138335, score: 17
# Scores: (min: 10, avg: 22, max: 63)
#
# Run: 21, exploration: 0.1255322834371622, score: 14
# Scores: (min: 10, avg: 21.61904761904762, max: 63)
#
# Run: 22, exploration: 0.11999500148501063, score: 10
# Scores: (min: 10, avg: 21.09090909090909, max: 63)
#
# Run: 23, exploration: 0.1085487359239089, score: 21
# Scores: (min: 10, avg: 21.08695652173913, max: 63)
#
# Run: 24, exploration: 0.10119240105273684, score: 15
# Scores: (min: 10, avg: 20.833333333333332, max: 63)
#
# Run: 25, exploration: 0.07836551983717477, score: 52
# Scores: (min: 10, avg: 22.08, max: 63)
#
# Run: 26, exploration: 0.07416156859737154, score: 12
# Scores: (min: 10, avg: 21.692307692307693, max: 63)
#
# Run: 27, exploration: 0.06317096204211972, score: 33
# Scores: (min: 10, avg: 22.11111111111111, max: 63)
#
# Run: 28, exploration: 0.058889873488111255, score: 15
# Scores: (min: 10, avg: 21.857142857142858, max: 63)
#
# Run: 29, exploration: 0.05601075525639029, score: 11
# Scores: (min: 10, avg: 21.482758620689655, max: 63)
#
# Run: 30, exploration: 0.05354009722551939, score: 10
# Scores: (min: 10, avg: 21.1, max: 63)
#
# Run: 31, exploration: 0.05143559895690903, score: 9
# Scores: (min: 9, avg: 20.70967741935484, max: 63)
#
# Run: 32, exploration: 0.04916675299948831, score: 10
# Scores: (min: 9, avg: 20.375, max: 63)
#
# Run: 33, exploration: 0.043159025252331236, score: 27
# Scores: (min: 9, avg: 20.575757575757574, max: 63)
#
# Run: 34, exploration: 0.04104898613852031, score: 11
# Scores: (min: 9, avg: 20.294117647058822, max: 63)
#
# Run: 35, exploration: 0.03884689602888724, score: 12
# Scores: (min: 9, avg: 20.057142857142857, max: 63)
#
# Run: 36, exploration: 0.032924408985721944, score: 34
# Scores: (min: 9, avg: 20.444444444444443, max: 63)
#
# Run: 37, exploration: 0.03131473892591842, score: 11
# Scores: (min: 9, avg: 20.18918918918919, max: 63)
#
# Run: 38, exploration: 0.027214167668287145, score: 29
# Scores: (min: 9, avg: 20.42105263157895, max: 63)
#
# Run: 39, exploration: 0.022720922640519125, score: 37
# Scores: (min: 9, avg: 20.846153846153847, max: 63)
#
# Run: 40, exploration: 0.019353724157029815, score: 33
# Scores: (min: 9, avg: 21.15, max: 63)
#
# Run: 41, exploration: 0.016988875991640028, score: 27
# Scores: (min: 9, avg: 21.29268292682927, max: 63)
#
# Run: 42, exploration: 0.01583754189442009, score: 15
# Scores: (min: 9, avg: 21.142857142857142, max: 63)
#
# Run: 43, exploration: 0.013558238831322046, score: 32
# Scores: (min: 9, avg: 21.3953488372093, max: 63)
#
# Run: 44, exploration: 0.012388500230681249, score: 19
# Scores: (min: 9, avg: 21.34090909090909, max: 63)
#
# Run: 45, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 21.933333333333334, max: 63)
#
# Run: 46, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 22.67391304347826, max: 63)
#
# Run: 47, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 23.23404255319149, max: 63)
#
# Run: 48, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 24.4375, max: 81)
#
# Run: 49, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 24.6734693877551, max: 81)
#
# Run: 50, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 24.98, max: 81)
#
# Run: 51, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 26.313725490196077, max: 93)
#
# Run: 52, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 27.903846153846153, max: 109)
#
# Run: 53, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 29.150943396226417, max: 109)
#
# Run: 54, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 30.444444444444443, max: 109)
#
# Run: 55, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 31.854545454545455, max: 109)
#
# Run: 56, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 32.910714285714285, max: 109)
#
# Run: 57, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 35.12280701754386, max: 159)
#
# Run: 58, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 37.6551724137931, max: 182)
#
# Run: 59, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 39.47457627118644, max: 182)
#
# Run: 60, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 40.5, max: 182)
#
# Run: 61, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 42.77049180327869, max: 182)
#
# Run: 62, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 45.46774193548387, max: 210)
#
# Run: 63, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 48.41269841269841, max: 231)
#
# Run: 64, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 51.359375, max: 237)
#
# Run: 65, exploration: 0.01, score: 296
# Scores: (min: 9, avg: 55.12307692307692, max: 296)
#
# Run: 66, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 56.196969696969695, max: 296)
#
# Run: 67, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 58.44776119402985, max: 296)
#
# Run: 68, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 60.23529411764706, max: 296)
#
# Run: 69, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 62.85507246376812, max: 296)
#
# Run: 70, exploration: 0.01, score: 278
# Scores: (min: 9, avg: 65.92857142857143, max: 296)
#
# Run: 71, exploration: 0.01, score: 285
# Scores: (min: 9, avg: 69.01408450704226, max: 296)
#
# Run: 72, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 71.34722222222223, max: 296)
#
# Run: 73, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 73.38356164383562, max: 296)
#
# Run: 74, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 75.58108108108108, max: 296)
#
# Run: 75, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 77.6, max: 296)
#
# Run: 76, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 80.22368421052632, max: 296)
#
# Run: 77, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 81.55844155844156, max: 296)
#
# Run: 78, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 82.87179487179488, max: 296)
#
# Run: 79, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 85.11392405063292, max: 296)
#
# Run: 80, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 86.975, max: 296)
#
# Run: 81, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 88.18518518518519, max: 296)
#
# Run: 82, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 89.45121951219512, max: 296)
#
# Run: 83, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 90.66265060240964, max: 296)
#
# Run: 84, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 92.8452380952381, max: 296)
#
# Run: 85, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 93.70588235294117, max: 296)
#
# Run: 86, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 95.46511627906976, max: 296)
# Run: 87, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 97.57471264367815, max: 296)
#
# Run: 88, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 98.5340909090909, max: 296)
#
# Run: 89, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 99.78651685393258, max: 296)
#
# Run: 90, exploration: 0.01, score: 339
# Scores: (min: 9, avg: 102.44444444444444, max: 339)
#
# Run: 91, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 101.62637362637362, max: 339)
#
# Run: 92, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 102.02173913043478, max: 339)
#
# Run: 93, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 103.19354838709677, max: 339)
#
# Run: 94, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 104.20212765957447, max: 339)
#
# Run: 95, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 105.2, max: 339)
#
# Run: 96, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 106.35416666666667, max: 339)
#
# Run: 97, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 107.80412371134021, max: 339)
#
# Run: 98, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 108.57142857142857, max: 339)
#
# Run: 99, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 109.73737373737374, max: 339)
#
# Run: 100, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 110.11, max: 339)
#
# Run: 101, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 110.54, max: 339)
#
# Run: 102, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 112.19, max: 339)
#
# Run: 103, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 112.53, max: 339)
#
# Run: 104, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 113.87, max: 339)
#
# Run: 105, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 116.5, max: 339)
#
# Run: 106, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 117.99, max: 339)
#
# Run: 107, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 119.02, max: 339)
#
# Run: 108, exploration: 0.01, score: 387
# Scores: (min: 9, avg: 122.78, max: 387)
#
# Run: 109, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 123.04, max: 387)
#
# Run: 110, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 123.88, max: 387)
#
# Run: 111, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 125.94, max: 387)
#
# Run: 112, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 127.54, max: 387)
#
# Run: 113, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 129.77, max: 387)
#
# Run: 114, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 131.21, max: 387)
#
# Run: 115, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 133.38, max: 387)
#
# Run: 116, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 135.01, max: 387)
#
# Run: 117, exploration: 0.01, score: 304
# Scores: (min: 9, avg: 137.93, max: 387)
#
# Run: 118, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 139.84, max: 387)
#
# Run: 119, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 141.52, max: 387)
#
# Run: 120, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 143.35, max: 387)
#
# Run: 121, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 145.09, max: 387)
#
# Run: 122, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 147.75, max: 387)
#
# Run: 123, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 150.37, max: 387)
#
# Run: 124, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 152.57, max: 387)
#
# Run: 125, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 153.43, max: 387)
#
# Run: 126, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 156.03, max: 387)
#
# Run: 127, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 157.86, max: 387)
#
# Run: 128, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 158.63, max: 387)
#
# Run: 129, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 160.99, max: 387)
#
# Run: 130, exploration: 0.01, score: 323
# Scores: (min: 9, avg: 164.12, max: 387)
#
# Run: 131, exploration: 0.01, score: 203
# Scores: (min: 10, avg: 166.06, max: 387)
#
# Run: 132, exploration: 0.01, score: 240
# Scores: (min: 11, avg: 168.36, max: 387)
#
# Run: 133, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 170.36, max: 387)
#
# Run: 134, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 171.4, max: 387)
#
# Run: 135, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 173.23, max: 387)
#
# Run: 136, exploration: 0.01, score: 406
# Scores: (min: 11, avg: 176.95, max: 406)
#
# Run: 137, exploration: 0.01, score: 249
# Scores: (min: 15, avg: 179.33, max: 406)
#
# Run: 138, exploration: 0.01, score: 245
# Scores: (min: 15, avg: 181.49, max: 406)
#
# Run: 139, exploration: 0.01, score: 179
# Scores: (min: 15, avg: 182.91, max: 406)
#
# Run: 140, exploration: 0.01, score: 346
# Scores: (min: 15, avg: 186.04, max: 406)
#
# Run: 141, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 187.53, max: 406)
#
# Run: 142, exploration: 0.01, score: 175
# Scores: (min: 19, avg: 189.13, max: 406)
#
# Run: 143, exploration: 0.01, score: 183
# Scores: (min: 19, avg: 190.64, max: 406)
#
# Run: 144, exploration: 0.01, score: 267
# Scores: (min: 28, avg: 193.12, max: 406)
#
# Run: 145, exploration: 0.01, score: 284
# Scores: (min: 28, avg: 195.48, max: 406)
#
# Solved in 45 runs, 145 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
#     Explain how reinforcement learning concepts apply to the cartpole      problem.
#
# o	What is the goal of the agent in this case?
#
# The goal of the agent in this case is to balance the pole vertically on a moving cart for as long as possible, gaining a reward for every timestep.
#
# o	What are the various state values?
#
# The various state values are the cart position, pole angle, cart velocity, and pole angular velocity.
#
# o	What are the possible actions that can be performed?
#
# The possible actions that can be performed are moving the cart left or right to keep the pole upright for as long as possible.
#
# o	What reinforcement algorithm is used for this problem?
#
# The reinforcement algorithm used for this problem is a deep Q-learning algorithm (DQN).
#
#         Analyze how experience replay is applied to the cartpole problem.
# o	How does experience replay work in this algorithm?
#
# Experience replay works in this algorithm because it uses minibatches and stores the agent’s experiences that include state, action, reward, and next state. The Q-values are calculated for each state/action pair, if this pair continues the game play the Q-value will be positive, if this pair ends the game the Q-value will be negative.
#
# o	What is the effect of introducing a discount factor for calculating the future rewards?
#
# A discount factor, commonly referred to as GAMMA, that approaches 1 incentivizes the agent to prioritize long-term advantageous strategies and future rewards, thereby enabling more informed and strategic decision-making.
#
#            Analyze how neural networks are used in deep Q-learning.
#
# o	Explain the neural network architecture that is used in the cartpole problem.
#
# The neural network architecture that is used in the cartpole problem has an input layer that includes the state of the environment (pole angle, pole angular velocity, cart position, and cart velocity). This connects the hidden layers with Relu activation function that pulls out features and learns the representations of the input state. These layers connect to the output layer that has 2 outcomes for each action (Balawedjer, 2021).
#
# o	How does the neural network make the Q-learning algorithm more efficient?
#
# The neural network makes the Q-learning algorithm more efficient by allowing it to run faster by estimated Q values. These Q-values represent the rewards for each state/action pair which allows the agent to play more efficiently.
#
# o	What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#
# The values that I adjusted: GAMMA from 0.95 to 0.99, learning rate from 0.001 to 0.005, Exploration MIN from 0.01 to 0.005, and the Exploration Decay from 0.995 to 0.95. The base code output was solved in 129 runs, 229 total runs. After adjusting the value listed above, the output is solved in 45 runs, 145 total runs. Demonstrating that the agent was able to solve the problem faster with the averages very close in both examples, although the max value was higher in the base code.
#
# References:
# Hands-on practical: Implementing DQN for Cartpole. (n.d.). https://apxml.com/courses/intermediate-reinforcement-learning/chapter-2-deep-q-networks-dqn/dqn-cartpole-practical
#
# PyLessons. (n.d.). Default site title. Python Lessons. https://pylessons.com/CartPole-DDQN
#
# EITCA Academy. (2024a, June 11). What is the significance of the discount factor ( gamma ) in the context of reinforcement learning, and how does it influence the training and performance of a DRL agent? https://eitca.org/artificial-intelligence/eitc-ai-arl-advanced-reinforcement-learning/deep-reinforcement-learning/deep-reinforcement-learning-agents/examination-review-deep-reinforcement-learning-agents/what-is-the-significance-of-the-discount-factor-gamma-in-the-context-of-reinforcement-learning-and-how-does-it-influence-the-training-and-performance-of-a-drl-agent/#:~:text=The%20discount%20factor%20is%20a%20scalar%20value%20between,rewards%2C%20thus%20shaping%20the%20agent%27s%20behavior%20and%20strategy.
#
# Playing Cartpole with the actor-critic method  :  Tensorflow Core. TensorFlow. (n.d.). https://www.tensorflow.org/tutorials/reinforcement_learning/actor_critic
#
# Balawejder, M. (2022, February 20). Solving open ai’s cartpole using reinforcement learning part-2. Medium. https://medium.com/analytics-vidhya/solving-open-ais-cartpole-using-reinforcement-learning-part-2-73848cbda4f1
